# %% [markdown]
# # PRCP-1027-Skin Disorder

# %% [markdown]
# ## PROBLEM STATEMENT
#
# Task 1:-Prepare a complete data analysis report on the given data.
#
# Task 2:-Create a predictive model  using machine learning techniques to predict the various classes of skin disease.
#
# Task3:-Suggestions to the Doctors to identify the skin diseases of the patient at the earliest.

# %%
# Imporing the basic libraries

import numpy as np
import pandas as pd

# For Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# For Warning
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the datset
df=pd.read_csv('dataset_35_dermatology (1).csv', na_values=['?'])

# %%
# Checking the shape of the dataset
df.shape
# Out:
# (366, 35)

# %%
# Checking the first five rows of the dataset
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
# Checking the last five rows of the dataset
df.tail()
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 361                  0                   0                         0
# 362                  0                   0                         0
# 363                  2                   0                         2
# 364                  3                   0                         2
# 365                  0                   0                         0
#
#      knee_and_elbow_involvement  scalp_involvement  ...  \
# 361                           0                  0  ...
# ...

# %%
# Checking the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   erythema                                  366 non-null    int64
#  1   scaling                                   366 non-null    int64
#  2   definite_borders                          366 non-null    int64
#  3   itching                                   366 non-null    int64
#  4   koebner_phenomenon                        366 non-null    int64
#  5   polygonal_papules                         366 non-null    int64
#  6   follicular_papules                        366 non-null    int64
#  7   oral_mucosal_involvement                  366 non-null    int64
#  8   knee_and_elbow_involvement                366 non-null    int64
#  9   scalp_involvement                         366 non-null    int64
# ...

# %%
# basic stats of the dataset
df.describe()
# Out:
#          erythema     scaling  definite_borders     itching  \
# count  366.000000  366.000000        366.000000  366.000000
# mean     2.068306    1.795082          1.549180    1.366120
# std      0.664753    0.701527          0.907525    1.138299
# min      0.000000    0.000000          0.000000    0.000000
# 25%      2.000000    1.000000          1.000000    0.000000
# 50%      2.000000    2.000000          2.000000    1.000000
# 75%      2.000000    2.000000          2.000000    2.000000
# max      3.000000    3.000000          3.000000    3.000000
#
#        koebner_phenomenon  polygonal_papules  follicular_papules  \
# count          366.000000         366.000000          366.000000
# mean             0.633880           0.448087            0.166667
# std              0.908016           0.957327            0.570588
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# ...

# %%
# Checking for the missing values
df.isnull().sum()
# Out:
# erythema                                    0
# scaling                                     0
# definite_borders                            0
# itching                                     0
# koebner_phenomenon                          0
# polygonal_papules                           0
# follicular_papules                          0
# oral_mucosal_involvement                    0
# knee_and_elbow_involvement                  0
# scalp_involvement                           0
# family_history                              0
# melanin_incontinence                        0
# eosinophils_in_the_infiltrate               0
# PNL_infiltrate                              0
# fibrosis_of_the_papillary_dermis            0
# exocytosis                                  0
# acanthosis                                  0
# hyperkeratosis                              0
# parakeratosis                               0
# clubbing_of_the_rete_ridges                 0
# ...

# %% [markdown]
# #### OBSERVATION:

# %%
df['Age'].unique()
# Out:
# array([55.,  8., 26., 40., 45., 41., 18., 57., 22., 30., 20., 21., 10.,
#        65., 38., 23., 17., 51., 42., 44., 33., 43., 50., 34., nan, 15.,
#        46., 62., 35., 48., 12., 52., 60., 32., 19., 29., 25., 36., 13.,
#        27., 31., 28., 64., 39., 47., 16.,  0.,  7., 70., 37., 61., 67.,
#        56., 53., 24., 58., 49., 63., 68.,  9., 75.])

# %%
# Replace using median 
median = df['Age'].median()
df['Age'].fillna(median, inplace=True)

# %%
df['Age'] = df['Age'].replace(0,df['Age'].median())

# %%
df['Age'].unique()
# Out:
# array([55.,  8., 26., 40., 45., 41., 18., 57., 22., 30., 20., 21., 10.,
#        65., 38., 23., 17., 51., 42., 44., 33., 43., 50., 34., 35., 15.,
#        46., 62., 48., 12., 52., 60., 32., 19., 29., 25., 36., 13., 27.,
#        31., 28., 64., 39., 47., 16.,  7., 70., 37., 61., 67., 56., 53.,
#        24., 58., 49., 63., 68.,  9., 75.])

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
plt.figure(figsize=(10,5),dpi=100)
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.figure(figsize=(12,40),facecolor='white',dpi=100)
plotnumber=1

for col in df:
    if plotnumber<=30:
        ax=plt.subplot(10,3,plotnumber)
        sns.countplot(df[col])
        
        for label in ax.containers:
            ax.bar_label(label)
        
    plotnumber+=1
plt.tight_layout()

# %%
df['class'].unique()
# Out:
# array([2, 1, 3, 5, 4, 6], dtype=int64)

# %%
df_eda=df.copy()

# %%
df_eda['class']=df_eda['class'].map({1:'psoriasis',2:'seboreic_dermatitis',3: 'lichen_planus',4: 'pityriasis_rosea',5: 'cronic_dermatitis',6: 'pityriasis_rubra_pilaris'})

# %%
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
df_eda.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
plt.figure(figsize=(11,5),dpi=100)
ax=sns.countplot(df_eda['class'])
for label in ax.containers:
    ax.bar_label(label)
plt.show()

# %%
df_eda_1=df_eda[['erythema', 'scaling', 'definite_borders', 'itching',
       'koebner_phenomenon', 'polygonal_papules', 'follicular_papules',
       'oral_mucosal_involvement', 'knee_and_elbow_involvement',
       'scalp_involvement', 'melanin_incontinence',
       'eosinophils_in_the_infiltrate', 'PNL_infiltrate',
       'fibrosis_of_the_papillary_dermis', 'exocytosis', 'acanthosis',
       'hyperkeratosis', 'parakeratosis', 'clubbing_of_the_rete_ridges',
       'elongation_of_the_rete_ridges',
       'thinning_of_the_suprapapillary_epidermis', 'spongiform_pustule',
       'munro_microabcess', 'focal_hypergranulosis',
       'disappearance_of_the_granular_layer',
       'vacuolisation_and_damage_of_basal_layer', 'spongiosis',
       'saw-tooth_appearance_of_retes', 'follicular_horn_plug',
       'perifollicular_parakeratosis', 'inflammatory_monoluclear_inflitrate',
       'band-like_infiltrate', 'Age']]

# %%
df_eda_1.shape
# Out:
# (366, 33)

# %%
plt.figure(figsize=(10,100),dpi=100)
plotnumber=1

for col in df_eda_1:
    if plotnumber<=34:
        ax=plt.subplot(34,1,plotnumber)
        sns.swarmplot(x=df_eda['class'],y=df_eda_1[col],hue=df_eda['family_history'],data=df_eda_1)

    plotnumber+=1
plt.tight_layout()

# %%
plt.figure(figsize=(15,20),dpi=100)
plotnumber=1

for col in df_eda_1:
    if plotnumber<=33:
        ax=plt.subplot(11,3,plotnumber)
        sns.boxplot(df[col])

    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ## FEATURE SCALING

# %%
from sklearn.preprocessing import RobustScaler
sc=RobustScaler()
df['Age'] = sc.fit_transform(df[['Age']])

# %% [markdown]
# ## FEATURE SELECTION

# %%
# Checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
fig= plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), annot=True ,fmt='.2f',cmap="rainbow")
plt.show()

# %%
# Finding the correlation between two features

cor_matrix = df.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))


# List of all columns that shows correlation greater than 0.95

to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.90)]
print(to_drop)
# Out:
# ['melanin_incontinence', 'vacuolisation_and_damage_of_basal_layer', 'saw-tooth_appearance_of_retes', 'perifollicular_parakeratosis', 'band-like_infiltrate']

# %%
df.drop(['melanin_incontinence', 'vacuolisation_and_damage_of_basal_layer', 'saw-tooth_appearance_of_retes', 
         'perifollicular_parakeratosis', 'band-like_infiltrate'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0         2        2                 0        3                   0
# 1         3        3                 3        2                   1
# 2         2        1                 2        3                   1
# 3         2        2                 2        0                   0
# 4         2        3                 2        2                   2
#
#    polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  3                   0                         3
# 3                  0                   0                         0
# 4                  2                   0                         2
#
#    knee_and_elbow_involvement  scalp_involvement  ...  \
# 0                           1                  0  ...
# ...

# %%
df.shape
# Out:
# (366, 30)

# %% [markdown]
# ### TRAIN AND TEST SPLIT

# %%
X=df.iloc[:,:-1]
y=df['class']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %% [markdown]
# ## MODEL BUILDING

# %%
# MODELS

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
# MODEL EVALUATION
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# %% [markdown]
# ### LOGISTIC REGRESSION MODEL

# %%
logisticregression = LogisticRegression(C=1, multi_class='ovr',max_iter=100).fit(X_train, y_train)

# %%
print("Logistic Regression coefficients shape: ", logisticregression.coef_.shape)
print("Logistic Regression intercept shape: ", logisticregression.intercept_.shape)
# Out:
# Logistic Regression coefficients shape:  (6, 29)
# Logistic Regression intercept shape:  (6,)

# %%
y_train_pred_logR = logisticregression.predict(X_train) # training model 
y_test_pred_logR = logisticregression.predict(X_test) # testing model

# %%
#Evaluate Logistic Regression model:
print("Logistic Regression training set score: %f" % accuracy_score(y_train, y_train_pred_logR))
print("Logistic Regression test set score: %f" % accuracy_score(y_test, y_test_pred_logR))
# Out:
# Logistic Regression training set score: 0.996094
# Logistic Regression test set score: 0.963636

# %%
training_accuracy = []
test_accuracy = []
# try c values from 0.001 to 5:
c_settings = np.arange(0.001, 5, 0.5)
for i in c_settings:
    # build the model
    clf = LogisticRegression(C=i, multi_class='ovr', max_iter=100)
    clf.fit(X_train, y_train)
    # record training set accuracy
    training_accuracy.append(clf.score(X_train, y_train))
    # record generalization accuracy
    test_accuracy.append(clf.score(X_test, y_test))
plt.plot(c_settings, training_accuracy, label="training accuracy")
plt.plot(c_settings, test_accuracy, label="test accuracy")
plt.legend()

# %%
#Evaluate Logistic Regression model:
LogisticRegression_1=LogisticRegression(C=1.5, multi_class='ovr', max_iter=100).fit(X_train, y_train)

y_train_pred_train_logR_1 = LogisticRegression_1.predict(X_train) # training model 
y_test_pred_train_logR_1 = LogisticRegression_1.predict(X_test) # testing model 

print("Logistic Regression training set score: %f" % accuracy_score(y_train, y_train_pred_train_logR_1))
print("Logistic Regression test set score: %f" % accuracy_score(y_test, y_test_pred_train_logR_1))
# Out:
# Logistic Regression training set score: 0.992188
# Logistic Regression test set score: 0.972727

# %%
# Classification Report
print(classification_report(y_test, y_test_pred_train_logR_1, target_names=
                            ['psoriasis','seboreic_dermatitis','lichen_planus','pityriasis_rosea','cronic_dermatitis',
                             'pityriasis_rubra_pilaris']))
# Out:
#                           precision    recall  f1-score   support
#
#                psoriasis       1.00      1.00      1.00        40
#      seboreic_dermatitis       0.88      0.94      0.91        16
#            lichen_planus       1.00      1.00      1.00        19
#         pityriasis_rosea       0.93      0.87      0.90        15
#        cronic_dermatitis       1.00      1.00      1.00        16
# pityriasis_rubra_pilaris       1.00      1.00      1.00         4
#
#                 accuracy                           0.97       110
#                macro avg       0.97      0.97      0.97       110
#             weighted avg       0.97      0.97      0.97       110

# %%
logR_cm=confusion_matrix(y_test, y_test_pred_train_logR_1)
print('confusion_matrix:')
print(logR_cm)
# Out:
# confusion_matrix:
# [[40  0  0  0  0  0]
#  [ 0 15  0  1  0  0]
#  [ 0  0 19  0  0  0]
#  [ 0  2  0 13  0  0]
#  [ 0  0  0  0 16  0]
#  [ 0  0  0  0  0  4]]

# %% [markdown]
# ### KNN MODEL

# %%
knn_clf=KNeighborsClassifier()
knn_clf.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_train_pred_knn=knn_clf.predict(X_train)
y_test_pred_knn=knn_clf.predict(X_test)

# %%
#Evaluate KNN model:

print("KNN training set score: %f" % accuracy_score(y_train, y_train_pred_knn))
print("KNN test set score: %f" % accuracy_score(y_test, y_test_pred_knn))
# Out:
# KNN training set score: 0.980469
# KNN test set score: 0.963636

# %%
k_range = list(range(1, 20))
scores = []
for k in k_range:
    knn_1 = KNeighborsClassifier(n_neighbors=k)
    knn_1.fit(X_train, y_train)
    y_pred_knn = knn_1.predict(X_test)
    scores.append(accuracy_score(y_test, y_pred_knn))
    
# plot the relationship between K and testing accuracy
plt.plot(k_range, scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
# Out:
# Text(0, 0.5, 'Testing Accuracy')

# %%
# instantiate the model with the best known parameters
knn_clf_1 = KNeighborsClassifier(n_neighbors=16)

knn_clf_1.fit(X_train,y_train)

y_train_pred_knn_1=knn_clf_1.predict(X_train)
y_test_pred_knn_1=knn_clf_1.predict(X_test)

# %%
#Evaluate KNN model:

print("KNN training set score: %f" % accuracy_score(y_train, y_train_pred_knn_1))
print("KNN test set score: %f" % accuracy_score(y_test, y_test_pred_knn_1))
# Out:
# KNN training set score: 0.968750
# KNN test set score: 0.972727

# %%
knn_cm=confusion_matrix(y_test, y_test_pred_knn_1)
print('confusion_matrix:')
print(knn_cm)
# Out:
# confusion_matrix:
# [[40  0  0  0  0  0]
#  [ 0 15  0  1  0  0]
#  [ 0  0 17  2  0  0]
#  [ 0  0  0 15  0  0]
#  [ 0  0  0  0 16  0]
#  [ 0  0  0  0  0  4]]

# %%
# Classification Report
print(classification_report(y_test, y_test_pred_knn_1, target_names=
                            ['psoriasis','seboreic_dermatitis','lichen_planus','pityriasis_rosea','cronic_dermatitis',
                             'pityriasis_rubra_pilaris']))
# Out:
#                           precision    recall  f1-score   support
#
#                psoriasis       1.00      1.00      1.00        40
#      seboreic_dermatitis       1.00      0.94      0.97        16
#            lichen_planus       1.00      0.89      0.94        19
#         pityriasis_rosea       0.83      1.00      0.91        15
#        cronic_dermatitis       1.00      1.00      1.00        16
# pityriasis_rubra_pilaris       1.00      1.00      1.00         4
#
#                 accuracy                           0.97       110
#                macro avg       0.97      0.97      0.97       110
#             weighted avg       0.98      0.97      0.97       110

# %% [markdown]
# ## SVC

# %%
svc_clf = SVC(kernel='linear', gamma=1, C=1, decision_function_shape='ovr')
svc_clf.fit(X_train, y_train)
# Out:
# SVC(C=1, gamma=1, kernel='linear')

# %%
y_train_pred_svc=svc_clf.predict(X_train)
y_test_pred_svc=svc_clf.predict(X_test)

# %%
#Evaluate SVC model:

print("SVC training set score: %f" % accuracy_score(y_train, y_train_pred_svc))
print("SVC test set score: %f" % accuracy_score(y_test, y_test_pred_svc))
# Out:
# SVC training set score: 0.992188
# SVC test set score: 0.972727

# %%
svc_cm=confusion_matrix(y_test, y_test_pred_svc)
print('confusion_matrix:')
print(svc_cm)
# Out:
# confusion_matrix:
# [[40  0  0  0  0  0]
#  [ 0 15  0  1  0  0]
#  [ 0  0 18  1  0  0]
#  [ 0  1  0 14  0  0]
#  [ 0  0  0  0 16  0]
#  [ 0  0  0  0  0  4]]

# %%
# Classification Report
print(classification_report(y_test, y_test_pred_svc, target_names=
                            ['psoriasis','seboreic_dermatitis','lichen_planus','pityriasis_rosea','cronic_dermatitis',
                             'pityriasis_rubra_pilaris']))
# Out:
#                           precision    recall  f1-score   support
#
#                psoriasis       1.00      1.00      1.00        40
#      seboreic_dermatitis       0.94      0.94      0.94        16
#            lichen_planus       1.00      0.95      0.97        19
#         pityriasis_rosea       0.88      0.93      0.90        15
#        cronic_dermatitis       1.00      1.00      1.00        16
# pityriasis_rubra_pilaris       1.00      1.00      1.00         4
#
#                 accuracy                           0.97       110
#                macro avg       0.97      0.97      0.97       110
#             weighted avg       0.97      0.97      0.97       110

# %% [markdown]
# ## DECISION TREE

# %%
dt_clf = DecisionTreeClassifier(random_state=42)

# %%
dt_clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_train_pred_dt=dt_clf.predict(X_train)
y_test_pred_dt=dt_clf.predict(X_test)

# %%
#Evaluate DT model:

print("DT training set score: %f" % accuracy_score(y_train, y_train_pred_dt))
print("DT test set score: %f" % accuracy_score(y_test, y_test_pred_dt))
# Out:
# DT training set score: 1.000000
# DT test set score: 0.963636

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {'max_depth':range(3,20,1),
          'min_samples_leaf':range(1,20,1),
          'min_samples_split':range(2,20,1),
          'criterion':['gini','entropy']}

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=dt_clf,param_grid=params,cv=5,n_jobs=-1, verbose=True, scoring='accuracy')

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 11628 candidates, totalling 58140 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': range(3, 20),
#                          'min_samples_leaf': range(1, 20),
#                          'min_samples_split': range(2, 20)},
#              scoring='accuracy', verbose=True)

# %%
score_df = pd.DataFrame(grid_search.cv_results_)
score_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.012497      0.011691         0.003126        0.006253
# 1       0.012497      0.006248         0.003125        0.006249
# 2       0.003124      0.006248         0.003124        0.006248
# 3       0.006248      0.007653         0.003124        0.006248
# 4       0.006248      0.007652         0.006248        0.007653
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0            gini               3                      1
# 1            gini               3                      1
# 2            gini               3                      1
# 3            gini               3                      1
# 4            gini               3                      1
#
#   param_min_samples_split                                             params  \
# 0                       2  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# 1                       3  {'criterion': 'gini', 'max_depth': 3, 'min_sam...
# ...

# %%
print(grid_search.best_estimator_)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
dt_clf_1 = DecisionTreeClassifier(max_depth=5, random_state=42)

dt_clf_1.fit(X_train, y_train)

y_train_pred_dt_1=dt_clf_1.predict(X_train)
y_test_pred_dt_1=dt_clf_1.predict(X_test)

# %%
#Evaluate DT model:

print("DT training set score: %f" % accuracy_score(y_train, y_train_pred_dt_1))
print("DT test set score: %f" % accuracy_score(y_test, y_test_pred_dt_1))
# Out:
# DT training set score: 0.968750
# DT test set score: 0.927273

# %%
dt_cm=confusion_matrix(y_test, y_test_pred_dt_1)
print('confusion_matrix:')
print(dt_cm)
# Out:
# confusion_matrix:
# [[39  1  0  0  0  0]
#  [ 0 15  0  1  0  0]
#  [ 0  1 18  0  0  0]
#  [ 0  4  0 11  0  0]
#  [ 0  0  0  0 16  0]
#  [ 1  0  0  0  0  3]]

# %%
# Classification Report
print(classification_report(y_test, y_test_pred_dt_1, target_names=
                            ['psoriasis','seboreic_dermatitis','lichen_planus','pityriasis_rosea','cronic_dermatitis',
                             'pityriasis_rubra_pilaris']))
# Out:
#                           precision    recall  f1-score   support
#
#                psoriasis       0.97      0.97      0.97        40
#      seboreic_dermatitis       0.71      0.94      0.81        16
#            lichen_planus       1.00      0.95      0.97        19
#         pityriasis_rosea       0.92      0.73      0.81        15
#        cronic_dermatitis       1.00      1.00      1.00        16
# pityriasis_rubra_pilaris       1.00      0.75      0.86         4
#
#                 accuracy                           0.93       110
#                macro avg       0.93      0.89      0.91       110
#             weighted avg       0.94      0.93      0.93       110

# %% [markdown]
# ## RANDOM FOREST

# %%
rand_clf = RandomForestClassifier(random_state=42)

# %%
rand_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_train_pred_rand=rand_clf.predict(X_train)
y_test_pred_rand=rand_clf.predict(X_test)

# %%
#Evaluate DT model:

print("DT training set score: %f" % accuracy_score(y_train, y_train_pred_rand))
print("DT test set score: %f" % accuracy_score(y_test, y_test_pred_rand))
# Out:
# DT training set score: 1.000000
# DT test set score: 0.954545

# %%
grid_param = {'n_estimators': [10,30,50,70],
            'max_depth':range(2,20,2),
            'min_samples_leaf':range(1,20,1),
            'min_samples_split':range(2,20,1),
            'criterion':['gini','entropy'],
            'max_features':['auto','log2'],
            'bootstrap':[True, False]
}

# %%
# Instantiate the grid search model
grid_search_rand = GridSearchCV(estimator=rand_clf,param_grid=grid_param,cv=5,n_jobs=-1, verbose=True, scoring='accuracy')

# %%
#grid_search_rand.fit(X_train, y_train)

# %%
#grid_search.best_estimator_

# %%
# rand_clf_1 = RandomForestClassifier(max_depth=5, min_samples_leaf=5, random_state=42)

# rand_clf_1.fit(X_train, y_train)

# y_train_pred_rand_1=rand_clf_1.predict(X_train)
# y_test_pred_rand_1=rand_clf_1.predict(X_test)

# %%
# #Evaluate DT model:

# print("DT training set score: %f" % accuracy_score(y_train, y_train_pred_rand_1))
# print("DT test set score: %f" % accuracy_score(y_test, y_test_pred_rand_1))

# %%
# rand_cm=confusion_matrix(y_test, y_test_pred_rand_1)
# print('confusion_matrix:')
# print(rand_cm)

# %%
# # Classification Report
# print(classification_report(y_test, y_test_pred_rand_1, target_names=
#                             ['psoriasis','seboreic_dermatitis','lichen_planus','pityriasis_rosea','cronic_dermatitis',
#                              'pityriasis_rubra_pilaris']))
